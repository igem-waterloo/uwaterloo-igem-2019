# %%
using DiffEqBiological;
using DifferentialEquations;
using Plots;
using Latexify;
using NumericIO;

# %%
const Avogadro = 6.022140857e23;
const kda_mg_conversion = 1.66054e-18;

# %%
const LibA_K_m = 5800; # nmol
const LibA_V_max = 0.16; # nmol/min
const NAT1_k = 68; # nmol/(min*mg), error is plus or minus 8
const NAT1_weight = 33; # kDa

# %%
rn_influx = @reaction_network begin
    l, 0 --> X
    mm(X, v, K), X --> Y
    k, Y --> Z
    end l v K k;

# %%
latexify(rn_influx)
# Out:
# L"\begin{align}
# \frac{dX}{dt} =& l - \frac{v \cdot X}{K + X} \cdot X \\
# \frac{dY}{dt} =& \frac{v \cdot X}{K + X} \cdot X - k \cdot Y \\
# \frac{dZ}{dt} =& k \cdot Y
# \end{align}
# "

# %%
NAT1_conc = 1*10^(-12); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 0.5; # mol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600, 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [200., 200., 1800.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  110.97081840894919
#   74.27209017617758

# %%
NAT1_conc = 1*10^(-12); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 0.9; # nmol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600., 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [200., 400., 1800.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  149.3657306409519
#  133.6897623171197

# %%
NAT1_conc = 1*10^(-12); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 2; # nmol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600., 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [300., 1200., 18000.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  224.05458003264602
#  297.0883607047104

# %%
NAT1_conc = 1*10^(-11); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 0.5; # mol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600, 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [150., 50., 18000.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  110.97081840894919
#    7.427209017617759

# %%
NAT1_conc = 1*10^(-11); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 0.9; # mol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600, 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [200., 50., 18000.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  149.36573064095188
#   13.36897623171197

# %%
NAT1_conc = 1*10^(-11); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 2; # mol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600, 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [300., 100., 18000.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  224.05458003264602
#   29.70883607047104

# %%
NAT1_conc = 1*10^(-10); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 0.5; # mol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600, 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [150., 50., 18000.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  110.97081840895804
#    0.7427209017617761

# %%
NAT1_conc = 1*10^(-10); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 0.9; # mol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600, 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [200., 50., 18000.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  149.3657306409519
#    1.3368976231711969

# %%
NAT1_conc = 1*10^(-10); # mol
NAT1_conc_factor = (NAT1_conc*Avogadro)*(NAT1_weight*kda_mg_conversion); # mg
NAT1_rate = NAT1_k*NAT1_conc_factor; # 1/min

Linuron_influx_rate = 2; # mol

p = (Linuron_influx_rate, LibA_V_max, LibA_K_m, NAT1_rate);
u0 = [600, 0.001, 0.001]; # initial concentrations in nmol
tspan = (0., 1000.);

prob = ODEProblem(rn_influx, u0, tspan, p);
sol = solve(prob, DynamicSS(Tsit5()));
plot(sol)

# %%
u0 = [300., 50., 18000.]
ssprob = SteadyStateProblem(rn_influx, u0, p)
sssol  = solve(ssprob, SSRootfind())[1:2]
# Out:
# 2-element Array{Float64,1}:
#  224.05458003265292
#    2.9708836070471056
